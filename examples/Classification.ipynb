# %%
from pathomics_research_utils.data_generators import ClassificationDataGenerator
from pathomics_research_utils.models import AlexNet
from pathomics_research_utils import utils
import tensorflow as tf
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Model
import numpy as np
import os

# %%
#Hyperparams
lr = 1e-4
n_epochs = 5
num_classes = 3

# %%
data_dir = '/home/krypt/myStuff/projects/cancer-research/data/lymphoma_2/'

# %%
data_generator = ClassificationDataGenerator(images_dir=data_dir)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-2c84080db767> in <module>()
# ----> 1 data_generator = ClassificationDataGenerator(images_dir=data_dir)
#
# /usr/local/lib/python3.7/dist-packages/pathomics_research_utils/data_generators/classification_data_generator.py in __init__(self, images_dir, height, width, resize, batch_size, shuffle, augmentation, magnify, num_channels, num_classes)
#      40         self.len = len(self.images) // self.batch_size
#      41         if self.shuffle:
# ...

# %%
model = AlexNet(input_shape=(32,32,3), num_classes=3)

# %%
model.compile(optimizer='adam', learning_rate=lr, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit_generator(
    generator=data_generator,
    epochs=n_epochs
)

# %%
model.predict(utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/lymphoma_2/MCL//0.tif').astype(np.float64).reshape((1,32,32,3)))

# %%
def get_model():
    net = tf.keras.applications.ResNet50()
    y_pred = layers.Dense(num_classes, activation='sigmoid')(net.output)
    return Model(inputs=net.input, outputs=y_pred)

# %%
model = get_model()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
data_dir = '/home/krypt/myStuff/projects/cancer-research/data/lymphoma/'

# %%
data_generator = ClassificationDataGenerator(images_dir=data_dir, height=224, width=224, resize=True, batch_size=8, shuffle=True)

# %%
plateau_cb = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.2, patience=2, verbose=1, mode='min', min_delta=0.0001)

# %%
model.compile(optimizer='adam', learning_rate=lr, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit_generator(
    generator=data_generator,
    epochs=n_epochs,
    callbacks=[plateau_cb]
)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-efa2986abcde> in <module>()
#       2     generator=data_generator,
#       3     epochs=n_epochs,
# ----> 4     callbacks=[plateau_cb]
#       5 )
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1295         shuffle=shuffle,
#    1296         initial_epoch=initial_epoch,
# -> 1297         steps_name='steps_per_epoch')
#    1298
#    1299   def evaluate_generator(self,
#
# ...
