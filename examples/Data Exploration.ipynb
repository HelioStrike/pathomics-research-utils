# %%
from pathomics_research_utils import utils
import matplotlib.pyplot as plt

# %% [markdown]
# # Epithelium Segmentation

# %%
img = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/epi/8918_00007.tif')
mask = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/epi/masks/8918_00007_mask.png')

# %%
utils.displayImagesSideBySide([img, mask])

# %% [markdown]
# # Carcinoma Localization

# %%
#img = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/idc/10253/0/10253_idx5_x1001_y1001_class0.png')
#mask = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/idc/10253/1/10253_idx5_x501_y351_class1.png')

# %% [markdown]
# # Lymphocyte Detection

# %%
img = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/lymphocytes/HER2/lymphocyte/data/im1.tif')
boundary = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/lymphocytes/HER2/lymphocyte/manual_seg/boundary/image14L1.tif')
center = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/lymphocytes/HER2/lymphocyte/manual_seg/center/1m.tif')
center_combined = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/lymphocytes/HER2/lymphocyte/manual_seg/center/im1_seg.tif')

# %%
utils.displayImagesSideBySide([img, boundary, center, center_combined])

# %% [markdown]
# # Lymphoma Typing

# %%
cll = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/lymphoma/CLL/sj-03-2810_001.tif')
fl = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/lymphoma/FL/sj-05-1467-R1_001.tif')
mcl = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/lymphoma/MCL/sj-04-3077-R2_001.tif')
utils.displayImagesSideBySide([cll,fl,mcl])

# %% [markdown]
# # Mitosis Detection

# %%
img = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/mitosis/01_01.tif')
mask = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/mitosis/01_01_brmask.png')
dilated_mask = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/mitosis/01_01_cmask.png')
pc = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/mitosis/01_01_pc.png')
utils.displayImagesSideBySide([img,mask,dilated_mask,pc])

# %% [markdown]
# # Nuclei Segmentation

# %%
img = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/nuclei/10256_500_f00001_original.tif')
mask = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/nuclei/10256_500_f00001_mask.png')
utils.displayImagesSideBySide([img,mask])

# %% [markdown]
# # Tubule Segmentation

# %%
img = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/tubule/09-1339-01-1.bmp')
mask = utils.read_image('/home/krypt/myStuff/projects/cancer-research/data/tubule/09-1339-01-1_anno.bmp')
utils.displayImagesSideBySide([img,mask])
